# %% [markdown]
# <font size=6>**EDA dados de comércio eletrônico brasileiro.**
#
# <font size=4><B>Conjunto de dados públicos do comércio eletrônico brasileiro.</B>
#
# * <font size=3> Este é um conjunto de dados público de comércio eletrônico brasileiro de pedidos feitos na Olist Store . O conjunto de dados contém informações de 100 mil pedidos de 2016 a 2018 realizados em diversos mercados no Brasil. Seus recursos permitem a visualização de um pedido em múltiplas dimensões: desde o status do pedido, preço, desempenho de pagamento e frete até a localização do cliente, atributos do produto e, finalmente, avaliações escritas pelos clientes.
#
# **Contexto:**
# * <font size=3> Este conjunto de dados foi generosamente fornecido pela Olist, a maior loja de departamentos no mercado brasileiro. A Olist conecta pequenas empresas de todo o Brasil a canais sem complicações e com um único contrato. Esses comerciantes podem vender seus produtos através da Loja Olist e enviá-los diretamente aos clientes usando os parceiros de logística Olist.
#
# * <font size=3> Depois que um cliente compra o produto na Olist Store, um vendedor é notificado para atender a esse pedido. Assim que o cliente recebe o produto, ou a data estimada de entrega está vencida, o cliente recebe por e-mail uma pesquisa de satisfação onde pode dar uma nota sobre a experiência de compra e anotar alguns comentários.
#
# * <font size=3><B> Veja mais em nosso site: https://olist.com/pt-br/  </b>
#
# **OBS:**
# <font size=3> Estes são dados comerciais reais, porém foram tornados anônimos para não expor os comerciantes e clientes.
#
# <font size=4.5> **Informações sobre os dados:**
#
# Os dados estão separadado em 8 arquivos csv, sendo eles:
# 1. Conjunto de dados de clientes (olist_customers_dataset):
#     - Este conjunto de dados contém informações sobre o cliente e sua localização.
#
#
# 2. Conjunto de dados de itens do pedido (olist_order_items_dataset):
#     - Este conjunto de dados inclui dados sobre os itens adquiridos em cada pedido.
#
#
# 3. Conjunto de dados de pagamentos (olist_order_payments_dataset):
#     - Este conjunto de dados inclui dados sobre as opções de pagamento de pedidos.
#
#
# 4. Conjunto de dados de avaliações de pedidos (olist_order_reviews_dataset):
#     - Este conjunto de dados inclui dados sobre as avaliações feitas pelos clientes.
#     - Depois que um cliente compra o produto da Olist Store, um vendedor é notificado para atender a esse pedido. Assim que o cliente recebe o produto, ou a data estimada de entrega está vencida, o cliente recebe uma pesquisa de satisfação por e-mail onde pode dar uma nota sobre a experiência de compra e anotar alguns comentários.
#
#
# 5. Conjunto de dados do pedido (olist_orders_dataset):
#     - Este é o conjunto de dados principal. Em cada pedido, você pode encontrar todas as outras informações.
#
#
# 6. Conjunto de dados de produtos (olist_products_dataset):
#     - Este conjunto de dados inclui dados sobre os produtos vendidos pela Olist.
#
#
# 7. Conjunto de dados de vendedores (olist_sellers_dataset):
#     - Este conjunto de dados inclui dados sobre os vendedores que atenderam aos pedidos feitos na Olist.
#
#
# 8. Conjunto de dados de geolocalização (olist_geolocation_dataset):
#     - Este conjunto de dados contém informações dos CEPs brasileiros e suas coordenadas lat / lng.

# %% [markdown]
# # Importando libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# # Importando Dados

# %%
pedidos = pd.read_csv('data/olist_orders_dataset.csv') 
clientes = pd.read_csv('data/olist_customers_dataset.csv') 
itens_do_pedido = pd.read_csv('data/olist_order_items_dataset.csv') 
pagamentos_pedidos = pd.read_csv('data/olist_order_payments_dataset.csv')  
vendedores = pd.read_csv('data/olist_sellers_dataset.csv') 
produtos = pd.read_csv('data/olist_products_dataset.csv') 
localizacao = pd.read_csv('data/olist_geolocation_dataset.csv')

# %% [markdown]
# ## Mesclando todos os dados em uma tabela

# %% [markdown]
# * <B>Esquema dos dados
#
# Os dados são divididos em vários conjuntos de dados para melhor compreensão e organização. Consulte o seguinte esquema de dados ao trabalhar com ele:
#
# ![](https://i.imgur.com/HRhd2Y0.png)

# %%
df = pd.merge(pedidos,itens_do_pedido,left_on='order_id',right_on='order_id')
df = df.merge(pagamentos_pedidos,on ='order_id')
df = df.merge(clientes,on ='customer_id')
df = df.merge(produtos,on ='product_id')
df = df.merge(localizacao,  left_on='customer_zip_code_prefix', right_on='geolocation_zip_code_prefix')

# %% [markdown]
# ## Visualizando Dados

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 4    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2017-10-04 19:55:00           2017-10-10 21:25:13
# 4          2017-10-04 19:55:00           2017-10-10 21:25:13
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00              1
# 1           2017-10-18 00:00:00              1
# 2           2017-10-18 00:00:00              1
# 3           2017-10-18 00:00:00              1
# 4           2017-10-18 00:00:00              1
#
#                          product_id  ... product_photos_qty product_weight_g  \
# 0  87285b34884572647811a353c7ac498a  ...                4.0            500.0
# 1  87285b34884572647811a353c7ac498a  ...                4.0            500.0
# 2  87285b34884572647811a353c7ac498a  ...                4.0            500.0
# 3  87285b34884572647811a353c7ac498a  ...                4.0            500.0
# 4  87285b34884572647811a353c7ac498a  ...                4.0            500.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               19.0                8.0              13.0
# 1               19.0                8.0              13.0
# 2               19.0                8.0              13.0
# 3               19.0                8.0              13.0
# 4               19.0                8.0              13.0
#
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                        3149       -23.574809       -46.587471
# 1                        3149       -23.578333       -46.587123
# 2                        3149       -23.574809       -46.587471
# 3                        3149       -23.575033       -46.587451
# 4                        3149       -23.580054       -46.586673
#
#   geolocation_city  geolocation_state
# 0        sao paulo                 SP
# 1        sao paulo                 SP
# 2        sao paulo                 SP
# 3        sao paulo                 SP
# 4        sao paulo                 SP
#
# [5 rows x 35 columns]

# %%
print('{} Linhas e {} colunas'.format(df.shape[0], df.shape[1]))
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# 17954162 Linhas e 35 colunas
# Quantidade de dados nulos: 1614472

# %% [markdown]
# **Verificando informações do df**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17954162 entries, 0 to 17954161
# Data columns (total 35 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       object
#  1   customer_id                    object
#  2   order_status                   object
#  3   order_purchase_timestamp       object
#  4   order_approved_at              object
#  5   order_delivered_carrier_date   object
#  6   order_delivered_customer_date  object
#  7   order_estimated_delivery_date  object
#  8   order_item_id                  int64
#  9   product_id                     object
#  10  seller_id                      object
#  11  shipping_limit_date            object
#  12  price                          float64
#  13  freight_value                  float64
#  14  payment_sequential             int64
#  15  payment_type                   object
#  16  payment_installments           int64
#  17  payment_value                  float64
#  18  customer_unique_id             object
#  19  customer_zip_code_prefix       int64
#  20  customer_city                  object
#  21  customer_state                 object
#  22  product_category_name          object
#  23  product_name_lenght            float64
#  24  product_description_lenght     float64
#  25  product_photos_qty             float64
#  26  product_weight_g               float64
#  27  product_length_cm              float64
#  28  product_height_cm              float64
#  29  product_width_cm               float64
#  30  geolocation_zip_code_prefix    int64
#  31  geolocation_lat                float64
#  32  geolocation_lng                float64
#  33  geolocation_city               object
#  34  geolocation_state              object
# dtypes: float64(12), int64(5), object(18)
# memory usage: 4.8+ GB

# %% [markdown]
# Aqui já podemos verificar que a base de dados contém 35 colunas e um total de 17954162 itens.

# %% [markdown]
# * Vamos dar uma olhada nas colunas que têm valores nulos e limpá-los, depois vamos verificar todos os tipos de dados e ver quais precisam ser convertidos para análise futuras.
#
# <font size=4> Antes disso vamos começar traduzindo as Colunas.

# %%
# Criando um dicionário com as traduções das colunas
colunas_traduzidas = {'order_id': 'id_pedido',
                     'customer_id': 'cliente_id',
                     'order_status': 'status_pedido',
                     'order_purchase_timestamp': 'data_hora_compra',
                     'order_approved_at': 'pedido_aprovado_em',
                     'order_delivered_carrier_date': 'data_entrega_pedido_a_transportadora',
                     'order_delivered_customer_date': 'entregue_ao_cliente_em',
                     'order_estimated_delivery_date': 'previsao_entrega',
                     'order_item_id': 'id_item_pedido',
                     'product_id': 'id_produto',
                     'seller_id': 'id_vendedor',
                     'shipping_limit_date': 'data_limite_envio',
                     'price': 'preco_compra',
                     'freight_value': 'preco_frete',
                     'payment_sequential': 'sequenci_pagamentos',
                     'payment_type': 'tipo_pagamento',
                     'payment_installments': 'numero_parcelas',
                     'payment_value': 'valor_pagamento',
                     'customer_unique_id': 'cliente_id_unico',
                     'customer_zip_code_prefix': 'codigo_postal_cliente',
                     'customer_city': 'cidade_cliente',
                     'customer_state': 'estado_cliente',
                     'product_category_name': 'nome_categoria_produto', 
                     'product_name_lenght': 'comprimento_nome_produto',
                     'product_description_lenght': 'comprimento_descricao_produto',
                     'product_photos_qty': 'qtd_fotos_produto', 
                     'product_weight_g': 'peso_produto_g',
                     'product_length_cm': 'comprimento_produto_cm', 
                     'product_height_cm': 'altura_produto_cm', 
                     'product_width_cm': 'largura_produto_cm'}

# %%
# Traduzindo colunas
df.rename(columns=colunas_traduzidas, inplace=True)

# %% [markdown]
# ## Verificando dados duplicados

# %% [markdown]
# * Para verificar se há dados duplicados de pedidos vamos olhar as colunas chaves do nosso df.

# %%
df[['id_pedido', 'cliente_id', 'data_hora_compra', 'id_produto']].head()
# Out:
#                           id_pedido                        cliente_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#       data_hora_compra                        id_produto
# 0  2017-10-02 10:56:33  87285b34884572647811a353c7ac498a
# 1  2017-10-02 10:56:33  87285b34884572647811a353c7ac498a
# 2  2017-10-02 10:56:33  87285b34884572647811a353c7ac498a
# 3  2017-10-02 10:56:33  87285b34884572647811a353c7ac498a
# 4  2017-10-02 10:56:33  87285b34884572647811a353c7ac498a

# %% [markdown]
# * Como você pode observar temos muitas linhas duplicadas, então podemos eliminar essas linhas mantendo a primeira.

# %%
# removendo as linha duplicadas e mantendo sempre a primeira
df = df.drop_duplicates(subset={'id_pedido'}, keep='first', inplace=False)
# resetando o index
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Verificando dados nulos

# %%
# Visualizando as 5 primeiras linhas
df.head()
# Out:
#                           id_pedido                        cliente_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  70b35acffdf851e782ebf6fbc35eb620  8e8ee9b08afb49b080d193f98b0505af
# 2  69923a4e07ce446644394df37a710286  31f31efcb333fcbad2b1371c8cf0fa84
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  ded23d37cdcc25b37b4473b7be770cb2  f96144f946e8e590fabf60a3a1e3342e
#
#   status_pedido     data_hora_compra   pedido_aprovado_em  \
# 0     delivered  2017-10-02 10:56:33  2017-10-02 11:07:15
# 1     delivered  2018-03-22 17:23:21  2018-03-22 18:05:36
# 2     delivered  2017-09-04 11:26:38  2017-09-04 11:43:25
# 3     delivered  2017-08-15 18:29:31  2017-08-15 20:05:16
# 4     delivered  2018-07-26 18:25:40  2018-07-27 02:10:26
#
#   data_entrega_pedido_a_transportadora entregue_ao_cliente_em  \
# 0                  2017-10-04 19:55:00    2017-10-10 21:25:13
# 1                  2018-03-23 18:03:03    2018-03-25 17:22:41
# 2                  2017-09-04 21:22:15    2017-09-05 19:20:20
# 3                  2017-08-17 15:28:33    2017-08-18 14:44:43
# 4                  2018-08-02 14:13:00    2018-08-07 12:12:23
#
#       previsao_entrega  id_item_pedido                        id_produto  ...  \
# 0  2017-10-18 00:00:00               1  87285b34884572647811a353c7ac498a  ...
# 1  2018-04-04 00:00:00               1  6cc44821f36f3156c782da72dd634e47  ...
# 2  2017-09-15 00:00:00               1  9abb00920aae319ef9eba674b7d2e6ff  ...
# 3  2017-08-28 00:00:00               1  87285b34884572647811a353c7ac498a  ...
# 4  2018-08-20 00:00:00               1  a0b7d5a992ccda646f2d34e418fff5a0  ...
#
#   qtd_fotos_produto peso_produto_g  comprimento_produto_cm  altura_produto_cm  \
# 0               4.0          500.0                    19.0                8.0
# 1               1.0         1050.0                    38.0               10.0
# 2               1.0          350.0                    19.0               14.0
# 3               4.0          500.0                    19.0                8.0
# 4               2.0        12300.0                    40.0               40.0
#
#    largura_produto_cm geolocation_zip_code_prefix  geolocation_lat  \
# 0                13.0                        3149       -23.574809
# 1                38.0                        3149       -23.574809
# 2                12.0                        3149       -23.574809
# 3                13.0                        3366       -23.565578
# 4                40.0                        3366       -23.565578
#
#    geolocation_lng geolocation_city  geolocation_state
# 0       -46.587471        sao paulo                 SP
# 1       -46.587471        sao paulo                 SP
# 2       -46.587471        sao paulo                 SP
# 3       -46.534603        sao paulo                 SP
# 4       -46.534603        sao paulo                 SP
#
# [5 rows x 35 columns]

# %%
df.isnull().sum()
# Out:
# id_pedido                                  0
# cliente_id                                 0
# status_pedido                              0
# data_hora_compra                           0
# pedido_aprovado_em                        14
# data_entrega_pedido_a_transportadora    1006
# entregue_ao_cliente_em                  2180
# previsao_entrega                           0
# id_item_pedido                             0
# id_produto                                 0
# id_vendedor                                0
# data_limite_envio                          0
# preco_compra                               0
# preco_frete                                0
# sequenci_pagamentos                        0
# tipo_pagamento                             0
# numero_parcelas                            0
# valor_pagamento                            0
# cliente_id_unico                           0
# codigo_postal_cliente                      0
# cidade_cliente                             0
# estado_cliente                             0
# nome_categoria_produto                  1407
# comprimento_nome_produto                1407
# comprimento_descricao_produto           1407
# qtd_fotos_produto                       1407
# peso_produto_g                            16
# comprimento_produto_cm                    16
# altura_produto_cm                         16
# largura_produto_cm                        16
# geolocation_zip_code_prefix                0
# geolocation_lat                            0
# geolocation_lng                            0
# geolocation_city                           0
# geolocation_state                          0
# dtype: int64

# %% [markdown]
# * Aqui podemos ver que as colunas:
#     - pedido_aprovado_em
#     - data_entrega_pedido_a_transportadora
#     - entregue_ao_cliente_em
#     - nome_categoria_produto
#     - peso_produto_g
#     - comprimento_produto_cm
#     - altura_produto_cm
#     - largura_produto_cm
#
#
# contém uma quantidade alta de dados nulos.
# * Vamos verificar o que essa quantidade representa do total da base de dados.

# %%
nan_cols = [i for i in df.columns if df[i].isnull().sum() >= 1]
for i in nan_cols:
    print(f"{i}:", "contém", np.round(df[i].isnull().mean() * 100, 2),
          '% dos dados nulos', 'e um total de',
          np.round(df[i].isnull().sum(), 4,), "linhas afetadas")
# Out:
# pedido_aprovado_em: contém 0.01 % dos dados nulos e um total de 14 linhas afetadas
# data_entrega_pedido_a_transportadora: contém 1.02 % dos dados nulos e um total de 1006 linhas afetadas
# entregue_ao_cliente_em: contém 2.22 % dos dados nulos e um total de 2180 linhas afetadas
# nome_categoria_produto: contém 1.43 % dos dados nulos e um total de 1407 linhas afetadas
# comprimento_nome_produto: contém 1.43 % dos dados nulos e um total de 1407 linhas afetadas
# comprimento_descricao_produto: contém 1.43 % dos dados nulos e um total de 1407 linhas afetadas
# qtd_fotos_produto: contém 1.43 % dos dados nulos e um total de 1407 linhas afetadas
# peso_produto_g: contém 0.02 % dos dados nulos e um total de 16 linhas afetadas
# comprimento_produto_cm: contém 0.02 % dos dados nulos e um total de 16 linhas afetadas
# altura_produto_cm: contém 0.02 % dos dados nulos e um total de 16 linhas afetadas
# largura_produto_cm: contém 0.02 % dos dados nulos e um total de 16 linhas afetadas

# %% [markdown]
# * Como podemos ver, que a quantidade de dados nulos contidos em cadas colunas não respresenta uma grande porcentagem do nosso df.
# * Diante disso irei limpá-los e incluir alguns valores a eles.

# %% [markdown]
# ### Tratando dados nulos

# %% [markdown]
# * Vamos preencher os nulos da 'preco_compra' com a média dos valores da própria coluna.

# %%
df['preco_compra'].fillna(df['preco_compra'].mean(), inplace=True)

# %% [markdown]
# * Preenchendo valores nulos da coluna 'preco_frete' com os valores médios.

# %%
df['preco_frete'].fillna(df['preco_frete'].mean(), inplace=True)

# %% [markdown]
# * Atribuindo valores não informado a coluna 'nome_categoria_produto'

# %%
df['nome_categoria_produto'].fillna('não informado', inplace=True)

# %% [markdown]
# * Atribuindo valores as variáveis de datas que serão usadas ao decorrer das analises

# %%
# Preenchendo os dados nulos da coluna 'pedido_aprovado_em' com os dados da data da compra
df["pedido_aprovado_em"].fillna(df["data_hora_compra"], inplace=True)
# preenchendo os dados nulos da coluna 'entregue_ao_cliente_em' com os dados da previsão de entrega
df['entregue_ao_cliente_em'].fillna(df['previsao_entrega'], inplace=True)

# %% [markdown]
# * Preenchendo os dados nulos das colunas abaixos com a media dos valores da própria coluna

# %%
df['peso_produto_g'].fillna(df['peso_produto_g'].mean(), inplace=True)
df['altura_produto_cm'].fillna(df['altura_produto_cm'].mean(), inplace=True)
df['comprimento_produto_cm'].fillna(df['comprimento_produto_cm'].mean(), inplace=True)
df['largura_produto_cm'].fillna(df['largura_produto_cm'].mean(), inplace=True)

# %% [markdown]
# * Removendo colunas que não seram usadas nas analises

# %%
df.drop(columns='data_entrega_pedido_a_transportadora',axis=1,inplace=True)
df.drop(columns='comprimento_nome_produto',axis=1,inplace=True)
df.drop(columns='comprimento_descricao_produto',axis=1,inplace=True)
df.drop(columns='qtd_fotos_produto',axis=1,inplace=True)

# %% [markdown]
# * Verificando os nulos após os tratamentos.

# %%
df.isnull().sum()
# Out:
# id_pedido                      0
# cliente_id                     0
# status_pedido                  0
# data_hora_compra               0
# pedido_aprovado_em             0
# entregue_ao_cliente_em         0
# previsao_entrega               0
# id_item_pedido                 0
# id_produto                     0
# id_vendedor                    0
# data_limite_envio              0
# preco_compra                   0
# preco_frete                    0
# sequenci_pagamentos            0
# tipo_pagamento                 0
# numero_parcelas                0
# valor_pagamento                0
# cliente_id_unico               0
# codigo_postal_cliente          0
# cidade_cliente                 0
# estado_cliente                 0
# nome_categoria_produto         0
# peso_produto_g                 0
# comprimento_produto_cm         0
# altura_produto_cm              0
# largura_produto_cm             0
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print('{} Linhas e {} colunas'.format(df.shape[0], df.shape[1]))
print('Quantidade de dados nulos:', df.isna().sum().sum())
# Out:
# 98391 Linhas e 31 colunas
# Quantidade de dados nulos: 0

# %% [markdown]
# ## Verificando e alterando os tipos dos dados

# %% [markdown]
# * Verificando as categorias de cada coluna para realizar as conversões onde for necessário.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98391 entries, 0 to 98390
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_pedido                    98391 non-null  object
#  1   cliente_id                   98391 non-null  object
#  2   status_pedido                98391 non-null  object
#  3   data_hora_compra             98391 non-null  object
#  4   pedido_aprovado_em           98391 non-null  object
#  5   entregue_ao_cliente_em       98391 non-null  object
#  6   previsao_entrega             98391 non-null  object
#  7   id_item_pedido               98391 non-null  int64
#  8   id_produto                   98391 non-null  object
#  9   id_vendedor                  98391 non-null  object
#  10  data_limite_envio            98391 non-null  object
#  11  preco_compra                 98391 non-null  float64
#  12  preco_frete                  98391 non-null  float64
#  13  sequenci_pagamentos          98391 non-null  int64
#  14  tipo_pagamento               98391 non-null  object
#  15  numero_parcelas              98391 non-null  int64
#  16  valor_pagamento              98391 non-null  float64
#  17  cliente_id_unico             98391 non-null  object
#  18  codigo_postal_cliente        98391 non-null  int64
#  19  cidade_cliente               98391 non-null  object
#  20  estado_cliente               98391 non-null  object
#  21  nome_categoria_produto       98391 non-null  object
#  22  peso_produto_g               98391 non-null  float64
#  23  comprimento_produto_cm       98391 non-null  float64
#  24  altura_produto_cm            98391 non-null  float64
#  25  largura_produto_cm           98391 non-null  float64
#  26  geolocation_zip_code_prefix  98391 non-null  int64
#  27  geolocation_lat              98391 non-null  float64
#  28  geolocation_lng              98391 non-null  float64
#  29  geolocation_city             98391 non-null  object
#  30  geolocation_state            98391 non-null  object
# dtypes: float64(9), int64(5), object(17)
# memory usage: 23.3+ MB

# %% [markdown]
# *  Podemos ver que as colunas de datas forão armazenadas no tipo de dados do 'object', então vamos convertê-los para datetime.
# * E as colunas de lat e lng estão com o tipo 'float64' e vamos alterar ambas para 'object' para não atrapalhar nossas análises futuras com as features numéricas.

# %%
colunas_de_datas = ['data_hora_compra','pedido_aprovado_em',
                    'entregue_ao_cliente_em','previsao_entrega',
                    'data_limite_envio']

for colunas in colunas_de_datas:
    df[colunas] = df[colunas].astype('datetime64[ns]')

# %%
colunas= ['geolocation_lat', 'geolocation_lng']
for coluna in colunas:
    df[coluna] = df[coluna].astype('object')

# %% [markdown]
# # Iniciando Analises

# %% [markdown]
# * Separando as features numéricas e time series para analises futuras.

# %%
numericas = [x for x in df.columns if df[x].dtype == 'float64']
time_series = [x for x in df.columns if df[x].dtype == 'datetime64[ns]']

# %%
df[numericas].describe()
# Out:
#        preco_compra   preco_frete  valor_pagamento  peso_produto_g  \
# count  98391.000000  98391.000000     98391.000000    98391.000000
# mean     125.892501     20.180164       157.952002     2103.489830
# std      191.214616     15.917385       218.080081     3765.001523
# min        0.850000      0.000000         0.010000        0.000000
# 25%       41.800000     13.250000        60.000000      300.000000
# 50%       79.000000     16.350000       103.360000      700.000000
# 75%      139.900000     21.210000       175.080000     1800.000000
# max     6735.000000    409.680000     13664.080000    40425.000000
#
#        comprimento_produto_cm  altura_produto_cm  largura_produto_cm
# count            98391.000000       98391.000000        98391.000000
# mean                30.103573          16.489494           23.027487
# std                 16.120003          13.323902           11.738612
# min                  7.000000           2.000000            6.000000
# 25%                 18.000000           8.000000           15.000000
# 50%                 25.000000          13.000000           20.000000
# 75%                 38.000000          20.000000           30.000000
# max                105.000000         105.000000          118.000000

# %% [markdown]
# ## Analisando Feature Numericas

# %%
for feature in numericas:
      if df[feature].dtype:    
        plt.figure(figsize=(10, 6))
        plt.style.use('seaborn')
        sns.histplot(df[feature], bins=30, kde=True, color='purple')
        plt.show()

# %% [markdown]
# <B>Algumas percepções notáveis sobre recursos numéricos:</B>
#
#
# * Referentes a (preço da compra, preço do frete):
#     - Podemos concluir que o preço da compra tem sua maioria <200,00 e o frete <50,00
#
# * Sobre dimensões do produto (Peso, altura, largura):
#    - Pode-se concluir que a maioria dos produtos tem dimensões pequenas, pois a maioria dos produtos tem altura menor que 20 cm, largura <30 cm, comprimento <60 cm e peso <5000 gms.

# %% [markdown]
# ## Analisando a variável 'preco_frete'

# %% [markdown]
# * Verificando a média do valor do frete por Estado

# %%
media_frete_por_estado = df.groupby('estado_cliente')[['preco_frete']].mean()

media_frete_por_estado.sort_values(by='preco_frete',
                                   ascending=False).style.format(
                                       {'preco_frete': 'R$ {:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_026cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >preco_frete</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >estado_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_026cc_level0_row0" class="row_heading level0 row0" >RO</th>
#       <td id="T_026cc_row0_col0" class="data row0 col0" >R$ 42.56</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row1" class="row_heading level0 row1" >RR</th>
#       <td id="T_026cc_row1_col0" class="data row1 col0" >R$ 42.26</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row2" class="row_heading level0 row2" >PB</th>
#       <td id="T_026cc_row2_col0" class="data row2 col0" >R$ 41.82</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row3" class="row_heading level0 row3" >AC</th>
#       <td id="T_026cc_row3_col0" class="data row3 col0" >R$ 41.30</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row4" class="row_heading level0 row4" >PI</th>
#       <td id="T_026cc_row4_col0" class="data row4 col0" >R$ 39.24</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row5" class="row_heading level0 row5" >MA</th>
#       <td id="T_026cc_row5_col0" class="data row5 col0" >R$ 38.24</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row6" class="row_heading level0 row6" >TO</th>
#       <td id="T_026cc_row6_col0" class="data row6 col0" >R$ 37.67</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row7" class="row_heading level0 row7" >RN</th>
#       <td id="T_026cc_row7_col0" class="data row7 col0" >R$ 36.74</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row8" class="row_heading level0 row8" >SE</th>
#       <td id="T_026cc_row8_col0" class="data row8 col0" >R$ 36.62</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row9" class="row_heading level0 row9" >AL</th>
#       <td id="T_026cc_row9_col0" class="data row9 col0" >R$ 36.09</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row10" class="row_heading level0 row10" >PA</th>
#       <td id="T_026cc_row10_col0" class="data row10 col0" >R$ 35.99</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row11" class="row_heading level0 row11" >AP</th>
#       <td id="T_026cc_row11_col0" class="data row11 col0" >R$ 35.02</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row12" class="row_heading level0 row12" >CE</th>
#       <td id="T_026cc_row12_col0" class="data row12 col0" >R$ 33.09</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row13" class="row_heading level0 row13" >AM</th>
#       <td id="T_026cc_row13_col0" class="data row13 col0" >R$ 33.07</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row14" class="row_heading level0 row14" >PE</th>
#       <td id="T_026cc_row14_col0" class="data row14 col0" >R$ 32.76</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row15" class="row_heading level0 row15" >MT</th>
#       <td id="T_026cc_row15_col0" class="data row15 col0" >R$ 28.62</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row16" class="row_heading level0 row16" >BA</th>
#       <td id="T_026cc_row16_col0" class="data row16 col0" >R$ 26.23</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row17" class="row_heading level0 row17" >MS</th>
#       <td id="T_026cc_row17_col0" class="data row17 col0" >R$ 24.30</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row18" class="row_heading level0 row18" >GO</th>
#       <td id="T_026cc_row18_col0" class="data row18 col0" >R$ 23.14</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row19" class="row_heading level0 row19" >ES</th>
#       <td id="T_026cc_row19_col0" class="data row19 col0" >R$ 22.15</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row20" class="row_heading level0 row20" >RS</th>
#       <td id="T_026cc_row20_col0" class="data row20 col0" >R$ 21.98</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row21" class="row_heading level0 row21" >SC</th>
#       <td id="T_026cc_row21_col0" class="data row21 col0" >R$ 21.75</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row22" class="row_heading level0 row22" >DF</th>
#       <td id="T_026cc_row22_col0" class="data row22 col0" >R$ 21.36</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row23" class="row_heading level0 row23" >RJ</th>
#       <td id="T_026cc_row23_col0" class="data row23 col0" >R$ 21.11</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row24" class="row_heading level0 row24" >MG</th>
#       <td id="T_026cc_row24_col0" class="data row24 col0" >R$ 20.82</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row25" class="row_heading level0 row25" >PR</th>
#       <td id="T_026cc_row25_col0" class="data row25 col0" >R$ 20.44</td>
#     </tr>
#     <tr>
#       <th id="T_026cc_level0_row26" class="row_heading level0 row26" >SP</th>
#       <td id="T_026cc_row26_col0" class="data row26 col0" >R$ 15.29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Neste resultado podemos verificar o estado de Rondônia tem o frete mais caro com a média de 42,56 reais comparado as todos os outro estados do brasil. E vemos que a cidade de São Paulo tem a o valor mais baixo do frete sendo R$ 15,29

# %% [markdown]
# * Representação Visual

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(16, 5))

# criando uma função para destacar cores
colors = []
values = media_frete_por_estado['preco_frete'].values.tolist()
for cor in values:
    if cor == max(values):
        colors.append('indianred')
    elif cor == min(values):
        colors.append('green')
    else:
        colors.append('cornflowerblue')
# atribuindo dados ao gráfico
ax.scatter(x=media_frete_por_estado.index,
           y=media_frete_por_estado["preco_frete"],
           c=colors)

# setando titulo do gráfico
ax.set_title("Valor Médio de Frete para cada Cidade", size=16)
# setando titulo eixo x
ax.set_xlabel("Estados", fontsize=14)
# setando titulo eixo y
ax.set_ylabel("Valor médio do Frete", fontsize=14)

# anotações maximo
plt.text(x=18,
         y=43,
         s="Frete Máximo \n     R${}".format(media_frete_por_estado.max()[0].round(2)),
         verticalalignment="top",
         fontsize=11,
         color="k")

# anotações minimo
plt.text(x=25.2,
         y=16.8,
         s="Frete Mínimo\n     R${}".format(media_frete_por_estado.min()[0].round(2)),
         verticalalignment="top",
         fontsize=11,
         color='k')

# configurações dos eixos
plt.yticks(range(15,50, 5), size=12)
plt.xticks(size=12)
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# ### Verificando a correlação do preço do frete com medidas e peso.

# %% [markdown]
# * Espera-se que o valor do frete dependa da categoria do pedido, preço, volume e peso: portanto, daremos uma olhada nessas relações nos dados.

# %%
# atribuindo dados a uma variável para plotagem
corr = df.corr()
corr.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c94c9_row0_col0, #T_c94c9_row1_col1, #T_c94c9_row2_col2, #T_c94c9_row3_col3, #T_c94c9_row4_col4, #T_c94c9_row5_col5, #T_c94c9_row6_col6, #T_c94c9_row6_col11, #T_c94c9_row7_col7, #T_c94c9_row8_col8, #T_c94c9_row9_col9, #T_c94c9_row10_col10, #T_c94c9_row11_col6, #T_c94c9_row11_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c94c9_row0_col1, #T_c94c9_row0_col2, #T_c94c9_row0_col7, #T_c94c9_row0_col8, #T_c94c9_row0_col9, #T_c94c9_row1_col0, #T_c94c9_row2_col0, #T_c94c9_row3_col4, #T_c94c9_row3_col5, #T_c94c9_row4_col3, #T_c94c9_row6_col10, #T_c94c9_row10_col6, #T_c94c9_row10_col11, #T_c94c9_row11_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c94c9_row0_col3, #T_c94c9_row1_col6, #T_c94c9_row1_col11, #T_c94c9_row6_col3, #T_c94c9_row11_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_c94c9_row0_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_c94c9_row0_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_c94c9_row0_col6, #T_c94c9_row0_col11, #T_c94c9_row3_col6, #T_c94c9_row3_col11 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c94c9_row0_col10, #T_c94c9_row6_col7, #T_c94c9_row7_col0, #T_c94c9_row7_col6, #T_c94c9_row7_col11, #T_c94c9_row11_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_c94c9_row1_col2, #T_c94c9_row2_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_c94c9_row1_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_c94c9_row1_col4, #T_c94c9_row1_col7, #T_c94c9_row4_col5 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c94c9_row1_col5 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_c94c9_row1_col8, #T_c94c9_row4_col9 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_c94c9_row1_col9, #T_c94c9_row2_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_c94c9_row1_col10, #T_c94c9_row9_col4 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_c94c9_row2_col3, #T_c94c9_row4_col6, #T_c94c9_row4_col11, #T_c94c9_row9_col3, #T_c94c9_row10_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c94c9_row2_col5 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_c94c9_row2_col6, #T_c94c9_row2_col11 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_c94c9_row2_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_c94c9_row2_col8 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_c94c9_row2_col9, #T_c94c9_row9_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_c94c9_row2_col10 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_c94c9_row3_col0, #T_c94c9_row6_col0, #T_c94c9_row8_col0, #T_c94c9_row11_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_c94c9_row3_col1, #T_c94c9_row10_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_c94c9_row3_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_c94c9_row3_col7, #T_c94c9_row3_col9, #T_c94c9_row6_col9, #T_c94c9_row11_col9 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c94c9_row3_col8, #T_c94c9_row3_col10, #T_c94c9_row5_col3, #T_c94c9_row8_col6, #T_c94c9_row8_col11, #T_c94c9_row9_col6, #T_c94c9_row9_col11 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c94c9_row4_col0, #T_c94c9_row5_col6, #T_c94c9_row5_col11, #T_c94c9_row6_col1, #T_c94c9_row7_col3, #T_c94c9_row8_col3, #T_c94c9_row11_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c94c9_row4_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_c94c9_row4_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_c94c9_row4_col7 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_c94c9_row4_col8 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_c94c9_row4_col10 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_c94c9_row5_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_c94c9_row5_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_c94c9_row5_col2, #T_c94c9_row7_col8 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_c94c9_row5_col4, #T_c94c9_row7_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_c94c9_row5_col7 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_c94c9_row5_col8 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_c94c9_row5_col9 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_c94c9_row5_col10 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c94c9_row6_col2, #T_c94c9_row11_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_c94c9_row6_col4, #T_c94c9_row11_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c94c9_row6_col5, #T_c94c9_row11_col5 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_c94c9_row6_col8, #T_c94c9_row9_col0, #T_c94c9_row11_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c94c9_row7_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_c94c9_row7_col4 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_c94c9_row7_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_c94c9_row7_col9 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_c94c9_row7_col10, #T_c94c9_row10_col7 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_c94c9_row8_col1, #T_c94c9_row8_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_c94c9_row8_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_c94c9_row8_col5, #T_c94c9_row10_col1, #T_c94c9_row10_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_c94c9_row8_col7 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_c94c9_row8_col9 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_c94c9_row8_col10 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_c94c9_row9_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_c94c9_row9_col5 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_c94c9_row9_col7 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_c94c9_row9_col8 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_c94c9_row9_col10 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_c94c9_row10_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_c94c9_row10_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_c94c9_row10_col8 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_c94c9_row10_col9 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# </style>
# <table id="T_c94c9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id_item_pedido</th>
#       <th class="col_heading level0 col1" >preco_compra</th>
#       <th class="col_heading level0 col2" >preco_frete</th>
#       <th class="col_heading level0 col3" >sequenci_pagamentos</th>
#       <th class="col_heading level0 col4" >numero_parcelas</th>
#       <th class="col_heading level0 col5" >valor_pagamento</th>
#       <th class="col_heading level0 col6" >codigo_postal_cliente</th>
#       <th class="col_heading level0 col7" >peso_produto_g</th>
#       <th class="col_heading level0 col8" >comprimento_produto_cm</th>
#       <th class="col_heading level0 col9" >altura_produto_cm</th>
#       <th class="col_heading level0 col10" >largura_produto_cm</th>
#       <th class="col_heading level0 col11" >geolocation_zip_code_prefix</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c94c9_level0_row0" class="row_heading level0 row0" >id_item_pedido</th>
#       <td id="T_c94c9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c94c9_row0_col1" class="data row0 col1" >-0.026380</td>
#       <td id="T_c94c9_row0_col2" class="data row0 col2" >-0.022515</td>
#       <td id="T_c94c9_row0_col3" class="data row0 col3" >-0.002573</td>
#       <td id="T_c94c9_row0_col4" class="data row0 col4" >0.043920</td>
#       <td id="T_c94c9_row0_col5" class="data row0 col5" >0.048563</td>
#       <td id="T_c94c9_row0_col6" class="data row0 col6" >-0.005304</td>
#       <td id="T_c94c9_row0_col7" class="data row0 col7" >-0.011040</td>
#       <td id="T_c94c9_row0_col8" class="data row0 col8" >-0.002814</td>
#       <td id="T_c94c9_row0_col9" class="data row0 col9" >-0.017014</td>
#       <td id="T_c94c9_row0_col10" class="data row0 col10" >0.003242</td>
#       <td id="T_c94c9_row0_col11" class="

# %% [markdown]
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>coeficiente de correlação</b> é uma medida de associação linear entre duas variáveis e situa-se entre <b>-1</b> e <b>+1</b> sendo que <b>-1</b> indica associação negativa perfeita e <b>+1</b> indica associação positiva perfeita.</p>
#
# * Como a amostragem acima podemos avaliar que a variável 'peso_produto_g tem uma correlação linear com o preço do frete, indicando que o aumento do peso influência o valor do frete.

# %%
# relação valor do frete vs peso do produto g
round(df['preco_frete'].corr(df['peso_produto_g']), 2)
# Out:
# 0.61

# %% [markdown]
# * Representação Visual

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 7))
# atribuindo dados ao gráfico
ax = sns.heatmap(corr, annot = True, fmt=".2f" , linewidths=0.4)
# configurações dos eixos
plt.xticks(size=12)
plt.yticks(size=12)
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# * Esta é a matriz gerada, a qual nos permitirá interpretar a relação entre as variávies. Nessa matriz podemos ver uma escala de cores de tonalidades de laranja, vermelho e roxo, e uma escala numérica que vai de 1 a -1. O interessante dessa representação gráfica é que além da barra lateral que demonstra a escala numérica do coeficiente e das cores, há também em cada quadrante o valor e a cor referente da relação.

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 5))
# atribuindo dados ao gráfico
df.plot(kind='scatter', x='peso_produto_g', y='preco_frete', ax=ax)
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# * Com essa visualização acima podemos confirmar a tese acima de que quanto mais pesado o item maior é o frete.

# %% [markdown]
# ## Analisando o volume de compras dos clientes por cidades.

# %%
pagamentos_por_UF = df.groupby('estado_cliente').agg(
    Contagem_por_Estado=('valor_pagamento', 'count'),
    Total_por_Estado=('valor_pagamento', 'sum'),
    Media_por_Estado=('valor_pagamento', 'mean'),
    Mediana_por_Estado=('valor_pagamento','median')).sort_values(by=('Contagem_por_Estado'),
                                                                 ascending=False)

pagamentos_por_UF['pct'] = pagamentos_por_UF['Total_por_Estado'].apply(
    lambda x: (x / sum(pagamentos_por_UF['Total_por_Estado'])))

pagamentos_por_UF.style.format({
    'Total_por_Estado': 'R$ {:,.2f}',
    'Media_por_Estado': 'R$ {:,.2f}',
    'Mediana_por_Estado': 'R$ {:,.2f}',
    'pct': '{:.1%}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_71157_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Contagem_por_Estado</th>
#       <th class="col_heading level0 col1" >Total_por_Estado</th>
#       <th class="col_heading level0 col2" >Media_por_Estado</th>
#       <th class="col_heading level0 col3" >Mediana_por_Estado</th>
#       <th class="col_heading level0 col4" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >estado_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71157_level0_row0" class="row_heading level0 row0" >SP</th>
#       <td id="T_71157_row0_col0" class="data row0 col0" >41359</td>
#       <td id="T_71157_row0_col1" class="data row0 col1" >R$ 5,825,466.86</td>
#       <td id="T_71157_row0_col2" class="data row0 col2" >R$ 140.85</td>
#       <td id="T_71157_row0_col3" class="data row0 col3" >R$ 92.50</td>
#       <td id="T_71157_row0_col4" class="data row0 col4" >37.5%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row1" class="row_heading level0 row1" >RJ</th>
#       <td id="T_71157_row1_col0" class="data row1 col0" >12749</td>
#       <td id="T_71157_row1_col1" class="data row1 col1" >R$ 2,089,739.71</td>
#       <td id="T_71157_row1_col2" class="data row1 col2" >R$ 163.91</td>
#       <td id="T_71157_row1_col3" class="data row1 col3" >R$ 109.42</td>
#       <td id="T_71157_row1_col4" class="data row1 col4" >13.4%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row2" class="row_heading level0 row2" >MG</th>
#       <td id="T_71157_row2_col0" class="data row2 col0" >11534</td>
#       <td id="T_71157_row2_col1" class="data row2 col1" >R$ 1,827,492.10</td>
#       <td id="T_71157_row2_col2" class="data row2 col2" >R$ 158.44</td>
#       <td id="T_71157_row2_col3" class="data row2 col3" >R$ 106.78</td>
#       <td id="T_71157_row2_col4" class="data row2 col4" >11.8%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row3" class="row_heading level0 row3" >RS</th>
#       <td id="T_71157_row3_col0" class="data row3 col0" >5428</td>
#       <td id="T_71157_row3_col1" class="data row3 col1" >R$ 870,206.37</td>
#       <td id="T_71157_row3_col2" class="data row3 col2" >R$ 160.32</td>
#       <td id="T_71157_row3_col3" class="data row3 col3" >R$ 106.88</td>
#       <td id="T_71157_row3_col4" class="data row3 col4" >5.6%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row4" class="row_heading level0 row4" >PR</th>
#       <td id="T_71157_row4_col0" class="data row4 col0" >4987</td>
#       <td id="T_71157_row4_col1" class="data row4 col1" >R$ 789,248.83</td>
#       <td id="T_71157_row4_col2" class="data row4 col2" >R$ 158.26</td>
#       <td id="T_71157_row4_col3" class="data row4 col3" >R$ 103.49</td>
#       <td id="T_71157_row4_col4" class="data row4 col4" >5.1%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row5" class="row_heading level0 row5" >SC</th>
#       <td id="T_71157_row5_col0" class="data row5 col0" >3612</td>
#       <td id="T_71157_row5_col1" class="data row5 col1" >R$ 602,251.89</td>
#       <td id="T_71157_row5_col2" class="data row5 col2" >R$ 166.74</td>
#       <td id="T_71157_row5_col3" class="data row5 col3" >R$ 108.94</td>
#       <td id="T_71157_row5_col4" class="data row5 col4" >3.9%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row6" class="row_heading level0 row6" >BA</th>
#       <td id="T_71157_row6_col0" class="data row6 col0" >3350</td>
#       <td id="T_71157_row6_col1" class="data row6 col1" >R$ 595,959.17</td>
#       <td id="T_71157_row6_col2" class="data row6 col2" >R$ 177.90</td>
#       <td id="T_71157_row6_col3" class="data row6 col3" >R$ 116.84</td>
#       <td id="T_71157_row6_col4" class="data row6 col4" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row7" class="row_heading level0 row7" >ES</th>
#       <td id="T_71157_row7_col0" class="data row7 col0" >2019</td>
#       <td id="T_71157_row7_col1" class="data row7 col1" >R$ 319,811.20</td>
#       <td id="T_71157_row7_col2" class="data row7 col2" >R$ 158.40</td>
#       <td id="T_71157_row7_col3" class="data row7 col3" >R$ 106.78</td>
#       <td id="T_71157_row7_col4" class="data row7 col4" >2.1%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row8" class="row_heading level0 row8" >GO</th>
#       <td id="T_71157_row8_col0" class="data row8 col0" >1998</td>
#       <td id="T_71157_row8_col1" class="data row8 col1" >R$ 341,860.59</td>
#       <td id="T_71157_row8_col2" class="data row8 col2" >R$ 171.10</td>
#       <td id="T_71157_row8_col3" class="data row8 col3" >R$ 111.42</td>
#       <td id="T_71157_row8_col4" class="data row8 col4" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row9" class="row_heading level0 row9" >DF</th>
#       <td id="T_71157_row9_col0" class="data row9 col0" >1956</td>
#       <td id="T_71157_row9_col1" class="data row9 col1" >R$ 317,638.75</td>
#       <td id="T_71157_row9_col2" class="data row9 col2" >R$ 162.39</td>
#       <td id="T_71157_row9_col3" class="data row9 col3" >R$ 108.09</td>
#       <td id="T_71157_row9_col4" class="data row9 col4" >2.0%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row10" class="row_heading level0 row10" >PE</th>
#       <td id="T_71157_row10_col0" class="data row10 col0" >1644</td>
#       <td id="T_71157_row10_col1" class="data row10 col1" >R$ 317,454.82</td>
#       <td id="T_71157_row10_col2" class="data row10 col2" >R$ 193.10</td>
#       <td id="T_71157_row10_col3" class="data row10 col3" >R$ 131.15</td>
#       <td id="T_71157_row10_col4" class="data row10 col4" >2.0%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row11" class="row_heading level0 row11" >CE</th>
#       <td id="T_71157_row11_col0" class="data row11 col0" >1323</td>
#       <td id="T_71157_row11_col1" class="data row11 col1" >R$ 268,118.38</td>
#       <td id="T_71157_row11_col2" class="data row11 col2" >R$ 202.66</td>
#       <td id="T_71157_row11_col3" class="data row11 col3" >R$ 128.09</td>
#       <td id="T_71157_row11_col4" class="data row11 col4" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row12" class="row_heading level0 row12" >PA</th>
#       <td id="T_71157_row12_col0" class="data row12 col0" >967</td>
#       <td id="T_71157_row12_col1" class="data row12 col1" >R$ 214,006.84</td>
#       <td id="T_71157_row12_col2" class="data row12 col2" >R$ 221.31</td>
#       <td id="T_71157_row12_col3" class="data row12 col3" >R$ 139.38</td>
#       <td id="T_71157_row12_col4" class="data row12 col4" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row13" class="row_heading level0 row13" >MT</th>
#       <td id="T_71157_row13_col0" class="data row13 col0" >901</td>
#       <td id="T_71157_row13_col1" class="data row13 col1" >R$ 184,292.60</td>
#       <td id="T_71157_row13_col2" class="data row13 col2" >R$ 204.54</td>
#       <td id="T_71157_row13_col3" class="data row13 col3" >R$ 125.05</td>
#       <td id="T_71157_row13_col4" class="data row13 col4" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row14" class="row_heading level0 row14" >MA</th>
#       <td id="T_71157_row14_col0" class="data row14 col0" >736</td>
#       <td id="T_71157_row14_col1" class="data row14 col1" >R$ 148,439.35</td>
#       <td id="T_71157_row14_col2" class="data row14 col2" >R$ 201.68</td>
#       <td id="T_71157_row14_col3" class="data row14 col3" >R$ 133.19</td>
#       <td id="T_71157_row14_col4" class="data row14 col4" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_71157_level0_row15" class="row_heading level0 row15" >MS</th>
#       <td id="T_71157_row15_col0" class="data row15 col0" >709</td>
#       <td id="T_71157_row15_col1" class="data row15 col1" >R$ 134,635.35</td>
#       <td id="T_71157_row15_col2" class="data row15 col2" >R$ 189.89</td>
#       <td id="T_71157_row15_col3" class="data row15 col3" >R$ 115.00</td>
#       <td id="T_71157_row15_col4" class="data row15 col4" >0.9%<

# %% [markdown]
# * Como podemos ver acima, 37,50% do total dos consumidores são de SP (São Paulo) com um volume de compras em reais de R$ 5,825,466.86, e com uma grande diferença para o segunda estado que é o RJ (Rio de Janeiro) que representa apenas 13.4% do total de compras feitas.

# %%
# Boxplots do gasto total por estado
fig = plt.figure(figsize=(10,5))
plt.style.use('seaborn')

sns.boxplot(x="estado_cliente", y="valor_pagamento", 
            data=df[df["valor_pagamento"]<500], color='#253760')

plt.xticks(rotation=90)
fig.tight_layout()

# %%
# setando cores
cinza_claro = "#CFCDCE"
cinza_medio = "#A2A1A3"
cinza_escuro = "#787878"
azul_claro = "lightskyblue"
azul_escuro = "#253760"

# %% [markdown]
#  * **Representação Visual**

# %%
vendas_estados = df.groupby('estado_cliente').count().sort_values(
    by='valor_pagamento', ascending=False).reset_index()[:15]

colors = []
values = vendas_estados['valor_pagamento'].values.tolist()
for maior in values:
    if maior == max(values):
        colors.append('crimson')
    else:
        colors.append('lightslategray')

fig, ax = plt.subplots(figsize=(10, 5))
plt.style.use('seaborn')

ax.bar(data=vendas_estados, x="estado_cliente", height="valor_pagamento", color=colors)
# configurações de layout ======================================================================
# setando titulo
ax.set_title(
    "15 principais estados com mais compras",
    fontsize=16,
    color=cinza_escuro,
)
# setando titulo eixo x
ax.set_xlabel("Estados", fontsize=12, color=cinza_escuro)
# setando titulo eixo y
ax.set_ylabel("Valor Pagamento")
# configurações de anotações do eixo x
plt.xticks(rotation=35, size=10, color=cinza_escuro)
# removendo grid
plt.grid(False)
# reovendo eixo y
plt.gca().axes.get_yaxis().set_visible(False)
#plt.gca().axes.get_xaxis().set_visible(False)

# função de notações das barras
n = range(vendas_estados.shape[0])
s = vendas_estados['valor_pagamento']
for i in range(len(s)):
    ax.annotate("{}".format(int(s[i])),
                xy=(n[i], s[i] * 1.01),
                fontsize=9,
                ha='center',
                va='bottom',
                color=cinza_escuro)

fig.tight_layout()

# %% [markdown]
# ## Número de pedidos por clientes.
# * Vamos ver a quantidade de pedido que um cliente costoma fazer

# %%
df_  = df.groupby("cliente_id_unico").agg({
    "id_pedido": "nunique"
}).sort_values(by='id_pedido', ascending=False)

# %%
fig = plt.figure(figsize=(10, 5))
plt.style.use('seaborn')

sns.histplot(df_,
             x="id_pedido",
             discrete=True,
             edgecolor="black",
             color=azul_escuro, alpha=0.8)
plt.xlabel("pedidos")
plt.title("Número de pedidos por Clientes")
plt.show()

# %% [markdown]
# * Podemos ver que a maioria dos clientes fizeram apenas um pedido.

# %% [markdown]
# ## Verificando quais são os clientes com mais compras

# %% [markdown]
# * Lembrando que não temos o nome dos clientes, mas temos o código ID unico de cada cliente.

# %%
top_clientes = df.groupby('cliente_id_unico').agg(Pedidos_por_cliente=(
    'cliente_id_unico', 'count')).sort_values(by='Pedidos_por_cliente', ascending=False)[:10]

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plt.style.use('seaborn')

ax.barh(y=top_clientes.index,
        width=top_clientes['Pedidos_por_cliente'],
        color=azul_escuro)

ax.set_title('10 Clientes com mais compras',
              fontsize=16)

ax.set_xlabel('Contagem', fontsize=15)
ax.set_ylabel('cliente_id_unico', fontsize=15)
fig.tight_layout()

# %% [markdown]
# * Nessa visualização podemos ver que poucos clientes fizeram mais de uma comprae  tem apenas um cliente que fez mais de um total de 16 pedidos.

# %% [markdown]
# ## Tipos de pagamento:
#    * Agora vamos ver os métodos de pagamento usados pelos clientes.

# %%
df['tipo_pagamento'].unique().tolist()
# Out:
# ['credit_card', 'boleto', 'voucher', 'debit_card']

# %% [markdown]
# * Como podemos ver exsitem 4 tipos de pagementos.
# * Antes de iniciarmos a analise vamos trazudir os tipos dessa coluna.

# %%
tipos = {'credit_card': 'Cartão de Crédito', 
         'voucher': 'Voucher',
         'boleto': 'Boleto',
         'debit_card': 'Cartão de Débito' }

df['tipo_pagamento'] = df['tipo_pagamento'].map(tipos)

# %%
df['tipo_pagamento'].unique().tolist()
# Out:
# ['Cartão de Crédito', 'Boleto', 'Voucher', 'Cartão de Débito']

# %%
df1 = df.groupby('tipo_pagamento').agg(Contagem=(
    'tipo_pagamento', 'count')).sort_values(by='Contagem', ascending=False)

df1['pct'] = df1.apply(lambda x: (x / ((x.sum()))))

df1.style.format({'pct': '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad080_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Contagem</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_pagamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad080_level0_row0" class="row_heading level0 row0" >Cartão de Crédito</th>
#       <td id="T_ad080_row0_col0" class="data row0 col0" >74675</td>
#       <td id="T_ad080_row0_col1" class="data row0 col1" >75.90%</td>
#     </tr>
#     <tr>
#       <th id="T_ad080_level0_row1" class="row_heading level0 row1" >Boleto</th>
#       <td id="T_ad080_row1_col0" class="data row1 col0" >19559</td>
#       <td id="T_ad080_row1_col1" class="data row1 col1" >19.88%</td>
#     </tr>
#     <tr>
#       <th id="T_ad080_level0_row2" class="row_heading level0 row2" >Voucher</th>
#       <td id="T_ad080_row2_col0" class="data row2 col0" >2638</td>
#       <td id="T_ad080_row2_col1" class="data row2 col1" >2.68%</td>
#     </tr>
#     <tr>
#       <th id="T_ad080_level0_row3" class="row_heading level0 row3" >Cartão de Débito</th>
#       <td id="T_ad080_row3_col0" class="data row3 col0" >1519</td>
#       <td id="T_ad080_row3_col1" class="data row3 col1" >1.54%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Visualização gráfica da porcentagem por tipo de pagamento

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(5, 5))
plt.style.use('seaborn')
# filtrando dados
pagamentos = df['tipo_pagamento'].value_counts()
#atribuindo dados ao gráfico
ax.pie(pagamentos,
       labels=pagamentos.index,
       autopct='%.2f%%',
       labeldistance=1.08)

# Configurações de design
centre_circle = plt.Circle((0, 0), 0.80, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax.axis('equal')
#setando a melhor visualização
plt.tight_layout()

# %% [markdown]
# * <b>Podemos ver que cerca de 94% dos pedidos são feitos por meio de cartão de crédito e boleto.</b>

# %% [markdown]
# * Visualização gráfica de quantidade de pagamento por tipo

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(7, 5))
plt.style.use('seaborn')
# filtrando dados
df1 = df.groupby(by='tipo_pagamento')[['cliente_id']].count().reset_index()
df1.rename(columns={'cliente_id': 'qtde_pagamentos'}, inplace=True)
#atribuindo dados ao gráfico
ax.bar(data=df1,
       x="tipo_pagamento",
       height="qtde_pagamentos",
       edgecolor="black", color=azul_escuro,
       alpha=0.8, width=0.9)

# configurações de layout ======================================================================
# setando titulo
ax.set_title(
    "Quantidade de Pagamento por Tipo",
    fontsize=16,
    color=cinza_escuro, loc='left')

# setando titulo eixo x
ax.set_xlabel("Tipo de Pagamento", fontsize=12,
              color=cinza_escuro, labelpad=10)
# configurações de anotações do eixo x
plt.xticks(size=12, color=cinza_escuro)
# removendo grid
plt.grid(False)
# reovendo eixo y
plt.gca().axes.get_yaxis().set_visible(False)
# plt.gca().axes.get_xaxis().set_visible(False)

# função de notações das barras
n = range(df1.shape[0])
s = df1['qtde_pagamentos']
for i in range(len(s)):
    ax.annotate("{}".format(int(s[i])),
                xy=(n[i], s[i] * 1.01),
                fontsize=9,
                ha='center',
                va='bottom',
                color=cinza_escuro)
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# * A maior quantidade de pagamentos foram feitos por cartão de crédito com um total de 74675 pagamento feitos, sendo 75.90% de todos os pagamentos.

# %% [markdown]
# * Visualizando a Distribuiçao do tipo de pagamento por estado

# %%
# Configurações do layout
ax = plt.subplots(figsize=(15, 5))
plt.style.use('seaborn')
#atribuindo dados ao gráfico
ax = sns.scatterplot(data=df,
                x='estado_cliente',
                y='preco_frete',
                hue='tipo_pagamento')
# configurações de layout
ax.set_title('Distribuiçao do tipo de pagamento por estado', size=18, color=cinza_escuro)
# visualizando
plt.show()

# %% [markdown]
# ## Analisando categorias dos produtos

# %%
print(
    
    "Contém {} tipos de categorias de produtos compartilhadas entres os clientes."
    .format(len(df['nome_categoria_produto'].unique()))
)
# Out:
# Contém 74 tipos de categorias de produtos compartilhadas entres os clientes.

# %% [markdown]
# * Tratando variável 'nome_categoria_produto'

# %%
df['nome_categoria_produto'] = df['nome_categoria_produto'].apply(
    lambda x: x.replace("_", " ")).apply(lambda x: x.title())

# %% [markdown]
# * Vamos dar uma olhada nas principais categorias de produtos que os clientes mais costumam comprar.

# %%
categoria_produto = df.groupby('nome_categoria_produto').agg(
    Contagem_categoria=('nome_categoria_produto', 'count')).sort_values(by='Contagem_categoria',
                                                                        ascending=False)[:10]

categoria_produto['pct_categoria'] = categoria_produto.apply(
    lambda x: (x / x.sum()))

categoria_produto.style.format({
    'pct_categoria': '{:.3%}'
}).background_gradient(cmap='Blues', subset=['pct_categoria'])
# Out:
# <style type="text/css">
# #T_da3cb_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_da3cb_row1_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_da3cb_row2_col1 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_da3cb_row3_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_da3cb_row4_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_da3cb_row5_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_da3cb_row6_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_da3cb_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_da3cb_row8_col1, #T_da3cb_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_da3cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Contagem_categoria</th>
#       <th class="col_heading level0 col1" >pct_categoria</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >nome_categoria_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da3cb_level0_row0" class="row_heading level0 row0" >Cama Mesa Banho</th>
#       <td id="T_da3cb_row0_col0" class="data row0 col0" >9311</td>
#       <td id="T_da3cb_row0_col1" class="data row0 col1" >15.015%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row1" class="row_heading level0 row1" >Beleza Saude</th>
#       <td id="T_da3cb_row1_col0" class="data row1 col0" >8767</td>
#       <td id="T_da3cb_row1_col1" class="data row1 col1" >14.137%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row2" class="row_heading level0 row2" >Esporte Lazer</th>
#       <td id="T_da3cb_row2_col0" class="data row2 col0" >7663</td>
#       <td id="T_da3cb_row2_col1" class="data row2 col1" >12.357%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row3" class="row_heading level0 row3" >Informatica Acessorios</th>
#       <td id="T_da3cb_row3_col0" class="data row3 col0" >6657</td>
#       <td id="T_da3cb_row3_col1" class="data row3 col1" >10.735%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row4" class="row_heading level0 row4" >Moveis Decoracao</th>
#       <td id="T_da3cb_row4_col0" class="data row4 col0" >6318</td>
#       <td id="T_da3cb_row4_col1" class="data row4 col1" >10.188%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row5" class="row_heading level0 row5" >Utilidades Domesticas</th>
#       <td id="T_da3cb_row5_col0" class="data row5 col0" >5815</td>
#       <td id="T_da3cb_row5_col1" class="data row5 col1" >9.377%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row6" class="row_heading level0 row6" >Relogios Presentes</th>
#       <td id="T_da3cb_row6_col0" class="data row6 col0" >5591</td>
#       <td id="T_da3cb_row6_col1" class="data row6 col1" >9.016%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row7" class="row_heading level0 row7" >Telefonia</th>
#       <td id="T_da3cb_row7_col0" class="data row7 col0" >4178</td>
#       <td id="T_da3cb_row7_col1" class="data row7 col1" >6.737%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row8" class="row_heading level0 row8" >Automotivo</th>
#       <td id="T_da3cb_row8_col0" class="data row8 col0" >3867</td>
#       <td id="T_da3cb_row8_col1" class="data row8 col1" >6.236%</td>
#     </tr>
#     <tr>
#       <th id="T_da3cb_level0_row9" class="row_heading level0 row9" >Brinquedos</th>
#       <td id="T_da3cb_row9_col0" class="data row9 col0" >3846</td>
#       <td id="T_da3cb_row9_col1" class="data row9 col1" >6.202%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Como podemos ver na tabela acima, os 5 primeiras categorias com mais compras; Cama mesa e banho, beleza e saúde, esportes e lazer, móveis e acessórios de informática juntas somam mais de de 50% das compras feitas pelos clientes, o que é bastante significativo, pois levando em conta que são 74 categorias no total disponíveis.

# %% [markdown]
# * Visualização gráfica das 10 principais categorias de produtos mais Comprados

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 5))
plt.style.use('seaborn')
# atribuindo dados ao gráfico
ax.barh(y=categoria_produto.index,
        width=categoria_produto['Contagem_categoria'],
        color=azul_escuro)
# configurações de titulos
ax.set_title('10 principais categorias de produtos mais Comprados',
             fontsize=16)

ax.set_xlabel('Quantidade', fontsize=15)
ax.set_ylabel('Categoria', fontsize=15)
# configurações dos eixos
plt.yticks(fontsize=12)
plt.xticks(range(0, 11000, 1000))
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# - Gasto médio em cada categoria:

# %%
preco_medio_categoria = df.groupby("nome_categoria_produto").agg(
    media_por_categoria=('preco_compra','mean')).sort_values(by='media_por_categoria',ascending=False)[:10]

preco_medio_categoria['pct'] = preco_medio_categoria.apply(
    lambda x: (x / x.sum()))


preco_medio_categoria.style.format({
    'media_por_categoria': 'R$ {:.2f}', 
    'pct': '{:.2%}'
}).background_gradient(cmap='Blues', subset=['pct'])
# Out:
# <style type="text/css">
# #T_6dce4_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6dce4_row1_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_6dce4_row2_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_6dce4_row3_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_6dce4_row4_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_6dce4_row5_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6dce4_row6_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_6dce4_row7_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_6dce4_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6dce4_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_6dce4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >media_por_categoria</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >nome_categoria_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dce4_level0_row0" class="row_heading level0 row0" >Pcs</th>
#       <td id="T_6dce4_row0_col0" class="data row0 col0" >R$ 1139.19</td>
#       <td id="T_6dce4_row0_col1" class="data row0 col1" >27.88%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row1" class="row_heading level0 row1" >Portateis Casa Forno E Cafe</th>
#       <td id="T_6dce4_row1_col0" class="data row1 col0" >R$ 627.82</td>
#       <td id="T_6dce4_row1_col1" class="data row1 col1" >15.37%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row2" class="row_heading level0 row2" >Eletrodomesticos 2</th>
#       <td id="T_6dce4_row2_col0" class="data row2 col0" >R$ 486.19</td>
#       <td id="T_6dce4_row2_col1" class="data row2 col1" >11.90%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row3" class="row_heading level0 row3" >Agro Industria E Comercio</th>
#       <td id="T_6dce4_row3_col0" class="data row3 col0" >R$ 352.96</td>
#       <td id="T_6dce4_row3_col1" class="data row3 col1" >8.64%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row4" class="row_heading level0 row4" >Instrumentos Musicais</th>
#       <td id="T_6dce4_row4_col0" class="data row4 col0" >R$ 296.90</td>
#       <td id="T_6dce4_row4_col1" class="data row4 col1" >7.27%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row5" class="row_heading level0 row5" >Eletroportateis</th>
#       <td id="T_6dce4_row5_col0" class="data row5 col0" >R$ 292.97</td>
#       <td id="T_6dce4_row5_col1" class="data row5 col1" >7.17%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row6" class="row_heading level0 row6" >Portateis Cozinha E Preparadores De Alimentos</th>
#       <td id="T_6dce4_row6_col0" class="data row6 col0" >R$ 282.21</td>
#       <td id="T_6dce4_row6_col1" class="data row6 col1" >6.91%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row7" class="row_heading level0 row7" >Construcao Ferramentas Seguranca</th>
#       <td id="T_6dce4_row7_col0" class="data row7 col0" >R$ 214.37</td>
#       <td id="T_6dce4_row7_col1" class="data row7 col1" >5.25%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row8" class="row_heading level0 row8" >Relogios Presentes</th>
#       <td id="T_6dce4_row8_col0" class="data row8 col0" >R$ 207.97</td>
#       <td id="T_6dce4_row8_col1" class="data row8 col1" >5.09%</td>
#     </tr>
#     <tr>
#       <th id="T_6dce4_level0_row9" class="row_heading level0 row9" >Moveis Quarto</th>
#       <td id="T_6dce4_row9_col0" class="data row9 col0" >R$ 184.84</td>
#       <td id="T_6dce4_row9_col1" class="data row9 col1" >4.52%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Como podemos observar na tabela acima, a categoria <B>computadores (pcs)</B> tem a maior média de gastos, cerca de <B>R$ 1139.19</B>, o que é bastante significativo, lembrando que são 74 categorias no tota.
# * Vale destacar que as 3 primeiras categoriras com maisor média de gastos <B>computadores (pcs), (Portateis Casa Forno E Cafe) e (Eletrodomesticos) </B>, juntos somam cerca de <B>54%</B> de todos os gastos médios.

# %% [markdown]
# * Visualização gráfica de Gasto médio em por categoria

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 5))
# atribuindo dados ao gráfico
ax.barh(y=preco_medio_categoria.index,
        width=preco_medio_categoria['media_por_categoria'],
        color=azul_escuro)
# configurações de titulos
ax.set_title('Gasto médio em por categoria',
             fontsize=16)
ax.set_xlabel('Quantidade', fontsize=15)
# configurações dos eixos
plt.xticks(range(0,1300, 100))
plt.yticks(fontsize=12)
#setando a melhor visualização
fig.tight_layout()

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 7))
# atribuindo dados ao gráfico
sns.boxplot(data=df[df['nome_categoria_produto'].isin(
    categoria_produto.index)],
            x='preco_compra',
            y='nome_categoria_produto',
            color=azul_escuro)
# configurações de titulos
ax.set_title('Distribuição de preços das principais categorias de produtos',
             fontsize=14)
ax.set_ylabel('categotia do Produto', fontsize=15)
ax.set_xlabel('Preço da Compra', fontsize=15)
# configurações dos eixos
plt.yticks(fontsize=15)
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# * Conforme figura, há muitos outliers para o mesmo produto, indicando grandes diferenças de preço e que afetam os cálculos médios acima.

# %% [markdown]
# ## Dias da semanas que mais são feitas as compras

# %%
df['dia_da_compra'] = df['data_hora_compra'].dt.day_name()

# %%
df['dia_da_compra'].unique().tolist()
# Out:
# ['Monday', 'Thursday', 'Tuesday', 'Sunday', 'Wednesday', 'Saturday', 'Friday']

# %% [markdown]
# * Traduzindo os dias da semana

# %%
dias = {
    'Monday': 'Segunda', 
    'Tuesday': 'Terça', 
    'Wednesday': 'Quarta',
    'Thursday': 'Quinta', 
    'Friday': 'Sexta', 
    'Saturday': 'Sábado', 
    'Sunday': 'Domingo'
}

df['dia_da_compra'] = df['dia_da_compra'].map(dias)

# %%
dia_da_compra = df.groupby(['dia_da_compra'])['id_pedido'].agg(
    ['count']).sort_values(by='count', ascending=False)

dia_da_compra.style.background_gradient(cmap='Blues', subset=['count'])
# Out:
# <style type="text/css">
# #T_879ba_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_879ba_row1_col0 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_879ba_row2_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_879ba_row3_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_879ba_row4_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_879ba_row5_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_879ba_row6_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_879ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dia_da_compra</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_879ba_level0_row0" class="row_heading level0 row0" >Segunda</th>
#       <td id="T_879ba_row0_col0" class="data row0 col0" >16023</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row1" class="row_heading level0 row1" >Terça</th>
#       <td id="T_879ba_row1_col0" class="data row1 col0" >15791</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row2" class="row_heading level0 row2" >Quarta</th>
#       <td id="T_879ba_row2_col0" class="data row2 col0" >15373</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row3" class="row_heading level0 row3" >Quinta</th>
#       <td id="T_879ba_row3_col0" class="data row3 col0" >14603</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row4" class="row_heading level0 row4" >Sexta</th>
#       <td id="T_879ba_row4_col0" class="data row4 col0" >13959</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row5" class="row_heading level0 row5" >Domingo</th>
#       <td id="T_879ba_row5_col0" class="data row5 col0" >11857</td>
#     </tr>
#     <tr>
#       <th id="T_879ba_level0_row6" class="row_heading level0 row6" >Sábado</th>
#       <td id="T_879ba_row6_col0" class="data row6 col0" >10785</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Podemos ver que, mais compras online acontecem durante a semana, destacando-se a segunda-feria com mais compras feitas 16023, seguido da terça e quarta com uma diferença pouca.

# %%
# Configurações do layout
fig, ax = plt.subplots(figsize=(7, 5))
# criando uma função para destacar cores
colors = []
values = dia_da_compra["count"].values
for maior in values:
    if maior == max(values):
        colors.append('indianred')
    else:
        colors.append(azul_escuro)

# atribuindo dados ao gráfico
ax.barh(y=dia_da_compra.index,
        width=dia_da_compra["count"],
        color=colors,
        edgecolor="black",
        alpha=0.8)
# configurações de titulos
ax.set_title('Dias da semanas que mais compras são feitas',
             fontsize=14,
             color=cinza_escuro)
ax.set_xlabel('Dia', fontsize=12, color=cinza_escuro)

#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# ## Analisando vendas por ano

# %% [markdown]
# * Extraindo apenas mes e ano da data da compra.
# * Traduzindo os meses

# %%
df['Mes'] = df['data_hora_compra'].dt.month_name()
df['Ano'] = df['data_hora_compra'].dt.year

meses = {'January': 'Janeiro',
         'February': 'Fevereiro',
         'March': 'Março',
         'April': 'Abril',
         'May': 'Maio',
         'June': 'Junho',
         'July': 'Julho', 
         'August': 'Agosto', 
         'September': 'Setembro', 
         'October': 'Outubro', 
         'November': 'Novembro', 
         'December': 'Dezembro'}

df['Mes'] = df['Mes'].map(meses)

# %% [markdown]
# * Visualizando compras ao longo de meses em cada ano

# %%
order = [
    'Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
    'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'
]
# Configurações do layout
fig, ax = plt.subplots(figsize=(10, 5))
# atribuindo dados ao gráfico
ax = sns.countplot(data=df,
                   x='Mes',
                   hue='Ano',
                   order=order,
                   palette='mako')
# configurações de titulos
ax.set_title('Pedidos comprado ao longo de meses em cada ano', fontsize=14)
ax.set_xlabel('Meses', fontsize=12)
ax.set_ylabel('Compras', fontsize=12)
# configurações dos eixos
ax.set_yticks(range(0, 11000, 1000))
plt.legend(loc='upper right')
#setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# * Como foi explicado os dados foram extraidos de 2016 até 2018, porém nem todos os meses estão completos, e podemos ver isso em 2016 que temos apenas um registro em Outubro.
# * Podemos destacar que dos meses disponíves em 2018 (8), foram todos superiores ao ano de 2017, exeto em Novembro/2017 que o foi mes com maior volume de compra 7429.

# %% [markdown]
# ## Analise geográfica de pedidos por Cidade

# %% [markdown]
# * Importando libs

# %%
from folium.plugins import MarkerCluster
import folium

# %% [markdown]
# * Incluindo a base de dados ao nosso df principal

# %% [markdown]
# ### Mapa Clusterizado

# %% [markdown]
# * Os mapas clusterizado costumam ser muito pesados, então Para fins didáticos irei visualizar apenas 70% dos dados de forma aleatória.

# %%
df_frac = df.sample(frac=0.7)

# %%
# importando libs
from tqdm import tqdm
# setando configurações basicas do mapa
mapa = folium.Map(location=[-12.415429388439524, -49.94279135900545],
                  zoom_start=5,
                  tiles='OpenStreetMap')

# atibuindo nome dos marcadores
cluster = MarkerCluster(name='Vendas')
# atribuindo dados e notações ao mapa
for venda in tqdm(df_frac.itertuples()):
    cluster.add_child(
        folium.Marker(
            location=[venda.geolocation_lat, venda.geolocation_lng],
            popup="<B>Tipo Produto:</B>\n" + str(venda.nome_categoria_produto) +
                  "<B><p>Tipo de Pagamento:</B>\n" + str(venda.tipo_pagamento) +
                  "<B><p>Data da Compra:</B>\n" + str(venda.data_hora_compra),
            icon=folium.Icon(color='blue',
                             prefix='fa',
                             icon='fa-shopping-cart')))

# adicionando cluster criando acima ao mapa
mapa.add_child(cluster)
# adicionando controle dos mapas
folium.LayerControl().add_to(mapa)
# salvar o mapa
mapa.save('mapas_olist/Olist_vendas.html')
# Out:
# 68874it [00:14, 4898.99it/s]

# %% [markdown]
# ### Mapa Choropleth

# %%
# importando libs
import geopandas as gpd
from pyproj import CRS
# imporatndo dados
brasil = gpd.read_file('data/mapas (shp)/mapa_brazil.shp')

# fitrando dados a partir da variável "pagamentos_por_UF"
vendas_estados = pagamentos_por_UF[[
    'Contagem_por_Estado'
]].sort_values(by='estado_cliente').reset_index()

# definindo variável para transformações dos dados
uf = {
    "AC": 'Acre',
    "AL": 'Alagoas',
    "AP": 'Amapá',
    "AM": 'Amazonas',
    "BA": 'Bahia',
    "CE": 'Ceará',
    "DF": 'Distrito Federal',
    "ES": 'Espírito Santo',
    "GO": 'Goiás',
    "MA": 'Maranhão',
    "MT": 'Mato Grosso',
    "MS": 'Mato Grosso do Sul',
    "MG": 'Minas Gerais',
    "PA": 'Pará',
    "PB": 'Paraíba',
    "PR": 'Paraná',
    "PE": 'Pernambuco',
    "PI": 'Piauí',
    "RJ": 'Rio de Janeiro',
    "RS": 'Rio Grande do Norte',
    "RN": 'Rio Grande do Sul',
    "RO": 'Rondônia',
    "RR": 'Roraima',
    "SC": 'Santa Catarina',
    "SP": 'São Paulo',
    "SE": 'Sergipe',
    "TO": 'Tocantins'
}

# aplicando alterações
vendas_estados['estado_cliente'] = vendas_estados['estado_cliente'].map(uf)

# mesclando dados com a tabela contendo a geolocalização
vendas_estados = vendas_estados.merge(brasil, 
                                     left_on='estado_cliente',
                                     right_on='ADM1_PT', 
                                     how= 'left')
# filtrando apenas colunas que serão usadas
vendas_estados = vendas_estados[['estado_cliente', 'Contagem_por_Estado', 'geometry']]

# setando crs 
crs_4326 = CRS("WGS84")
# trasnforando df em geodataframe
geo_dados = gpd.GeoDataFrame(vendas_estados, crs=crs_4326)
# visualizando todas as transformações feitas acima
geo_dados.head()
# Out:
#   estado_cliente  Contagem_por_Estado  \
# 0           Acre                   81
# 1        Alagoas                  410
# 2       Amazonas                  147
# 3          Amapá                   68
# 4          Bahia                 3350
#
#                                             geometry
# 0  MULTIPOLYGON (((-68.87747 -11.01987, -68.88027...
# 1  POLYGON ((-35.46317 -8.82467, -35.46457 -8.828...
# 2  MULTIPOLYGON (((-58.49367 -0.84197, -58.48917 ...
# 3  MULTIPOLYGON (((-50.46147 2.11133, -50.45627 2...
# 4  MULTIPOLYGON (((-38.70687 -17.96447, -38.70867...

# %% [markdown]
# * Vizualizando Geo Gráfico

# %%
# setando configurações basicas do mapa ( localização inicial, zoom e tipo de mapa)
mapa = folium.Map([-12.415429388439524, -49.94279135900545],
                  zoom_start=4,
                  tiles='OpenStreetMap')
# atribuindo dados ao mapa
choro = folium.Choropleth(
    geo_data=geo_dados,
    name='Brasil',
    data=geo_dados,
    columns=['estado_cliente', 'Contagem_por_Estado'],
    fill_opacity=0.2,
    line_opacity=0.3
).add_to(mapa)
# atribuindo labels contendo informações de cada cidades 
choro.geojson.add_child(
    folium.features.GeoJsonTooltip(
        fields=['estado_cliente', 'Contagem_por_Estado'],
        aliases=['Estado:', 'Pedidos:'],
        style=('background-color: white; color: k; font-size: 12px; padding: 5px;'),
        labels=True))

#adicionando controles do mapa
folium.LayerControl().add_to(mapa)
# salvar o mapa
mapa.save('mapas_olist/Olist_vendas_choropleth.html')

# %% [markdown]
# # Analisando Comentários Sobre os Pedidos

# %% [markdown]
# * Importando Dados com os Reviews

# %%
Reviews = pd.read_csv('data/olist_order_reviews_dataset.csv')

# %% [markdown]
# * Visualizando os 5 primeiros registros

# %%
Reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# * Filtrando apenas as culunas que serão analisadas

# %%
Reviews = Reviews[['review_score','review_comment_message']]
Reviews.head()
# Out:
#    review_score                             review_comment_message
# 0             4                                                NaN
# 1             5                                                NaN
# 2             5                                                NaN
# 3             5              Recebi bem antes do prazo estipulado.
# 4             5  Parabéns lojas lannister adorei comprar pela I...

# %% [markdown]
# * Tratando dados nulos

# %%
nan_cols = [i for i in Reviews.columns if Reviews[i].isnull().sum() >= 1]
for i in nan_cols:
    print(f"{i}:", "contém", np.round(Reviews[i].isnull().mean() * 100, 2),
          '% dos dados nulos', 'e um total de',
          np.round(Reviews[i].isnull().sum(), 4,), "linhas afetadas")
    print()
    print(f'Número de linha sem comentários : {Reviews[i].isnull().sum()}')
    print(f'Número de linha com comentários: {len(Reviews[i])-Reviews[i].isnull().sum()}')
# Out:
# review_comment_message: contém 58.25 % dos dados nulos e um total de 58247 linhas afetadas
#
# Número de linha sem comentários : 58247
# Número de linha com comentários: 41753

# %% [markdown]
# * Removendo dados nulos

# %%
Reviews.dropna(inplace=True)

# %% [markdown]
# * Visualizando alguns detalhes estatísticos básicos como percentil, média, padrão etc.

# %%
Reviews.describe()
# Out:
#        review_score
# count  41753.000000
# mean       3.640409
# std        1.626383
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# ## Verificando a Distribuição das Avaliações

# %% [markdown]
# * Representação Visual da Distribuição das Avaliações

# %%
# configurando layout
fig, ax = plt.subplots(figsize=(8, 5))
# filtrando dados 
review_score = Reviews.groupby('review_score').count()
# atribuindo dados ao gráfico
ax= sns.kdeplot(Reviews['review_score'])
# configurando titulos
ax.set_ylabel('Contagem')
ax.set_xlabel('Dristibuição das Avaliações')
# setando uma melhor visualização
fig.tight_layout()

# %% [markdown]
# * Podemos ver que os dados estão concentrados em torno da avaliação de 5 estrelas e da avaliação de 1 estrela.
#    <p>O que nos leva a presumir que, ou o cliente gostou muito do atendimento ou ele odiou e colocou a menor nota disponível.

# %% [markdown]
# ## Classificando Dados
#
# <p> Para essa analise irei classificar oa avaliações por sentimento onde (< 3 = 'neg') & (> 3 = 'pos')

# %% [markdown]
# <B>

# %%
def sentiment(x):
  if x< 3:
    return "neg"
  return "pos"

Reviews['sentimento'] = Reviews['review_score'].map(lambda c : sentiment(c))

# %%
Reviews.sample(5, random_state=42)
# Out:
#        review_score                             review_comment_message  \
# 1051              1  ABRI PROTOCOLO PARA DEVOLUÇÃO, PRODUTO DE BAIX...
# 83408             1                             Quero o valor de volta
# 37153             3  Iria comprar mais de voces, mais vi que quanto...
# 1434              3                               rapidez na entrega.
# 8457              1                           Produto veio com defeito
#
#       sentimento
# 1051         neg
# 83408        neg
# 37153        pos
# 1434         pos
# 8457         neg

# %%
sentimento = Reviews.groupby("sentimento").agg(Contagem=('sentimento', 'count'))

sentimento['pct'] = sentimento.apply(lambda x: (x / x.sum()))

sentimento.style.format({'pct': '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab56b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Contagem</th>
#       <th class="col_heading level0 col1" >pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sentimento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab56b_level0_row0" class="row_heading level0 row0" >neg</th>
#       <td id="T_ab56b_row0_col0" class="data row0 col0" >11408</td>
#       <td id="T_ab56b_row0_col1" class="data row0 col1" >27.32%</td>
#     </tr>
#     <tr>
#       <th id="T_ab56b_level0_row1" class="row_heading level0 row1" >pos</th>
#       <td id="T_ab56b_row1_col0" class="data row1 col0" >30345</td>
#       <td id="T_ab56b_row1_col1" class="data row1 col1" >72.68%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Podemos ver que a porcentagem de clientes satisfeitos é bem alta cerca de <B>72.68%</B>, que confirma nossa analise sobre a distribuição das avaliações, onde a quantidade de avaliações com 5 estrelas tem o maior peso.

# %% [markdown]
# * Representação Visual da Distribuição de sentimentos

# %%
# configurando layout
fig, ax = plt.subplots(figsize=(8, 5))
# # atribuindo dados ao gráfico
ax = sns.barplot(x=sentimento.index,
                 y=sentimento['Contagem'], color='purple')
# # configurações de titulos
ax.set_ylabel('Contagem')
ax.set_xlabel('Sentimento')
# configurações dos eixos
plt.xticks(size=12)
# setando a melhor visualização
fig.tight_layout()

# %% [markdown]
# ## Tratando os textos

# %% [markdown]
# ### Visualizando WordCloud

# %% [markdown]
# * Importando libs

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from nltk.tokenize import word_tokenize
import nltk

# %%
# Transformando coluna preprocessed em uma string unica
text = " ".join([x for x in Reviews['review_comment_message']])

# atribuindo dados a plotagem 
wordcloud = WordCloud(
    background_color="black",
    max_font_size=110,
    max_words=1000,
    collocations=True
).generate(text)

# configurando layout
plt.figure(figsize=[15, 15])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# visualizando
plt.show()

# %% [markdown]
# * Wordcloud ou nuvem de palavras é uma imagem que contém várias palavras, que podem ser feitas a partir de textos e o tamanho de cada palavra mostrada está relacionado com a frequência que a mesma aparece no texto.

# %% [markdown]
# * Como podemos ver a nossa nuvem de palavras está bem suja com muitas "Stop Words" que são As Stop Words são palavras que não necessitam ser indexadas, por possui pouco significado, tais como preposições, artigos, conjunções e outros.
# <p>
# <P> E para tornar melhor a analise irei fazer um tartamento para refinar a vizualização da nossa Wordcloud.

# %% [markdown]
# ### Stop Words - removendo o que não agrega

# %%
stopwords = set(nltk.corpus.stopwords.words('portuguese'))
print(stopwords)
# Out:
# {'o', 'ao', 'como', 'delas', 'minha', 'já', 'houverei', 'tivéramos', 'esteja', 'seu', 'houverá', 'tuas', 'teríamos', 'hão', 'lhes', 'estiverem', 'seremos', 'houvermos', 'teria', 'esses', 'no', 'for', 'estivemos', 'fomos', 'houver', 'estejam', 'tinha', 'deles', 'qual', 'fôssemos', 'fôramos', 'depois', 'pelo', 'teu', 'pelas', 'à', 'isto', 'foi', 'há', 'dele', 'mesmo', 'estavam', 'tenho', 'é', 'houverem', 'somos', 'hajamos', 'a', 'tenham', 'estou', 'me', 'nas', 'muito', 'seus', 'houvera', 'fossem', 'tenha', 'você', 'hei', 'está', 'um', 'só', 'este', 'tivéssemos', 'foram', 'tivera', 'houveriam', 'estejamos', 'numa', 'aquela', 'de', 'houvessem', 'mais', 'será', 'se', 'houveram', 'essa', 'estive', 'formos', 'estivéramos', 'houve', 'uma', 'teriam', 'para', 'tivesse', 'do', 'fui', 'serei', 'ela', 'suas', 'eram', 'eles', 'tu', 'vocês', 'aquilo', 'estava', 'seja', 'terei', 'são', 'hajam', 'terá', 'estiveram', 'teus', 'meu', 'dos', 'nosso', 'terão', 'houveremos', 'teve', 'estivermos', 'por', 'temos', 'estivessem', 'houvemos', 'meus', 'tivermos', 'estivera', 'com', 'tua', 'nem', 'tivemos', 'também', 'esteve', 'tinham', 'ou', 'tivessem', 'e', 'esta', 'havemos', 'não', 'ele', 'num', 'quando', 'seríamos', 'haja', 'aos', 'entre', 'às', 'estiver', 'pela', 'houveríamos', 'sua', 'teremos', 'era', 'tiver', 'sou', 'aquelas', 'pelos', 'sem', 'nos', 'fora', 'aquele', 'estivéssemos', 'te', 'houverão', 'tem', 'estivesse', 'isso', 'eu', 'aqueles', 'tiveram', 'éramos', 'houveria', 'mas', 'que', 'estão', 'tive', 'sejam', 'fosse', 'vos', 'forem', 'da', 'estas', 'nossos', 'essas', 'tínhamos', 'das', 'até', 'houvéssemos', 'em', 'esse', 'nossas', 'estes', 'minhas', 'tém', 'tenhamos', 'quem', 'tiverem', 'na', 'sejamos', 'dela', 'elas', 'houvesse', 'nós', 'serão', 'houvéramos', 'estamos', 'nossa', 'os', 'as', 'seria', 'lhe', 'estávamos', 'seriam'}

# %% [markdown]
# * Tokenização e remoção das stopwords

# %% [markdown]
# * Para isso irei usar a biblioteca NLTK e o método **tokenizetoken_space.tokenize()**
# <p>
#
#
# https://www.nltk.org/api/nltk.tokenize.html

# %%
# importando libs
from nltk import tokenize
# setando stopwords
stopwords = set(nltk.corpus.stopwords.words('portuguese'))

# criando list apara ser populada
words_processed = list()
# inicinando o tratamento
for word in Reviews['review_comment_message']:
    words = list()
    word = word.lower()
    token_space = tokenize.WhitespaceTokenizer()
    word_tokens = token_space.tokenize(word)
    for wd in word_tokens:
        if wd not in stopwords:
            words.append(wd)
    words_processed.append(" ".join(words))

# Atribuindo os dados tratados a uma nova coluna do df
Reviews['preprocessed'] = words_processed

# %% [markdown]
# * Visualizando comparação do tratamento

# %%
Reviews[['review_comment_message', 'preprocessed']][:5]
# Out:
#                                review_comment_message  \
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...
#
#                                          preprocessed
# 3                  recebi bem antes prazo estipulado.
# 4   parabéns lojas lannister adorei comprar intern...
# 9   aparelho eficiente. site marca aparelho impres...
# 12               pouco ,travando...pelo valor ta boa.
# 15  vendedor confiável, produto ok entrega antes p...

# %% [markdown]
# ### Retirando pontuação

# %% [markdown]
# * Para isso irei popular a nossa lista de stopwords com as pontuações do método punctuation da biblioteca string e irei aplicar novamente na coluna preprocessed.

# %%
# importando libs
from string import punctuation

# atribuindo pontuações a uma nova lista
punctuations = list()
for ponto in punctuation:
    punctuations.append(ponto)
# populando a nossa variável stopwords com as novas pontuações   
stopwords.update(punctuations)   
# setando método 
token_punctuation = tokenize.WordPunctTokenizer()
# inicinando o tratamento   
words_processed = list()
for word in Reviews['preprocessed']:
    words = list()
    word_tokens = token_punctuation.tokenize(word)
    for wd in word_tokens:
        if wd not in stopwords:
            words.append(wd)
    words_processed.append(" ".join(words))
    
# Atribuindo os dados tratados a uma nova coluna do df   
Reviews['preprocessed'] = words_processed

# %%
Reviews[['review_comment_message', 'preprocessed']][:5]
# Out:
#                                review_comment_message  \
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...
#
#                                          preprocessed
# 3                   recebi bem antes prazo estipulado
# 4   parabéns lojas lannister adorei comprar intern...
# 9   aparelho eficiente site marca aparelho impress...
# 12                    pouco travando ... valor ta boa
# 15  vendedor confiável produto ok entrega antes prazo

# %% [markdown]
# ### Retirando acentuação

# %% [markdown]
# * Nesse processo irei remover os acentos de todas as palvras do nosso texto.
# <p>
#     Para isso usarei a biblioteca unidecode e irei aplicar na nossa coluna preprocessed.

# %%
# importando libs
import unidecode
# removendo acentos
Reviews['preprocessed'] = [unidecode.unidecode(texto) for texto in Reviews['preprocessed']]

# %%
Reviews[['review_comment_message', 'preprocessed']][:5]
# Out:
#                                review_comment_message  \
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...
#
#                                          preprocessed
# 3                   recebi bem antes prazo estipulado
# 4   parabens lojas lannister adorei comprar intern...
# 9   aparelho eficiente site marca aparelho impress...
# 12                    pouco travando ... valor ta boa
# 15  vendedor confiavel produto ok entrega antes prazo

# %% [markdown]
# * Por fim, vamos verificar o resultado de todo o tratamento realizado.

# %% [markdown]
# ## WordCloud

# %% [markdown]
# * <font size=4> Depois do Tratamento

# %%
# Transformando coluna preprocessed em uma string unica
text = " ".join([x for x in Reviews['preprocessed']])
# carregando imagem da plotagem
background_image = np.array(Image.open('mask/br2.jpg'))
# atribuindo dados a plotagem 
wordcloud = WordCloud(
                  width=background_image.shape[1],
                  height=background_image.shape[0],
                  background_color="white",
                  mask=background_image,
                  max_font_size=110,
                  max_words=1000,
                  collocations=True
                      ).generate(text)
# configurando layout
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# visualizando
plt.show()
